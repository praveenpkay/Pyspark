ings XI Punjab</td><td>Royal Challengers Bangalore</td><td>bat</td><td>normal</td><td>0</td><td>Kings XI Punjab</td><td>0</td><td>8</td><td>AR Patel</td><td>Holkar Cricket Stadium</td><td>AK Chaudhary</td><td>C Shamshuddin</td><td>null</td></tr><tr><td>9</td><td>2017</td><td>Pune</td><td>2017-04-11</td><td>Delhi Daredevils</td><td>Rising Pune Supergiant</td><td>Rising Pune Supergiant</td><td>field</td><td>normal</td><td>0</td><td>Delhi Daredevils</td><td>97</td><td>0</td><td>SV Samson</td><td>Maharashtra Cricket Association Stadium</td><td>AY Dandekar</td><td>S Ravi</td><td>null</td></tr><tr><td>10</td><td>2017</td><td>Mumbai</td><td>2017-04-12</td><td>Sunrisers Hyderabad</td><td>Mumbai Indians</td><td>Mumbai Indians</td><td>field</td><td>normal</td><td>0</td><td>Mumbai Indians</td><td>0</td><td>4</td><td>JJ Bumrah</td><td>Wankhede Stadium</td><td>Nitin Menon</td><td>CK Nandan</td><td>null</td></tr><tr><td>11</td><td>2017</td><td>Kolkata</td><td>2017-04-13</td><td>Kings XI Punjab</td><td>Kolkata Knight Riders</td ...

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id: integer (nullable = true)
# -- season: integer (nullable = true)
# -- city: string (nullable = true)
# -- date: string (nullable = true)
# -- team1: string (nullable = true)
# -- team2: string (nullable = true)
# -- toss_winner: string (nullable = true)
# -- toss_decision: string (nullable = true)
# -- result: string (nullable = true)
# -- dl_applied: integer (nullable = true)
# -- winner: string (nullable = true)
# -- win_by_runs: integer (nullable = true)
# -- win_by_wickets: integer (nullable = true)
# -- player_of_match: string (nullable = true)
# -- venue: string (nullable = true)
# -- umpire1: string (nullable = true)
# -- umpire2: string (nullable = true)
# -- umpire3: string (nullable = true)
#
# </div>

# %%
rdd = df.rdd.map(list)
rdd.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [[1,
#   2017,
#   &#39;Hyderabad&#39;,
#   &#39;2017-04-05&#39;,
#   &#39;Sunrisers Hyderabad&#39;,
#   &#39;Royal Challengers Bangalore&#39;,
#   &#39;Royal Challengers Bangalore&#39;,
#   &#39;field&#39;,
#   &#39;normal&#39;,
#   0,
#   &#39;Sunrisers Hyderabad&#39;,
#   35,
#   0,
#   &#39;Yuvraj Singh&#39;,
#   &#39;Rajiv Gandhi International Stadium, Uppal&#39;,
#   &#39;AY Dandekar&#39;,
#   &#39;NJ Llong&#39;,
#   None],
#  [2,
#   2017,
#   &#39;Pune&#39;,
#   &#39;2017-04-06&#39;,
#   &#39;Mumbai Indians&#39;,
#   &#39;Rising Pune Supergiant&#39;,
#   &#39;Rising Pune Supergiant&#39;,
#   &#39;field&#39;,
#   &#39;normal&#39;,
#   0,
#   &#39;Rising Pune Supergiant&#39;,
#   0,
#   7,
#   &#39;SPD Smith&#39;,
#   &#39;Maharashtra Cricket Association Stadium&#39;,
#   &#39;A Nand Kishore&#39;,
#   &#39;S Ravi&#39;,
#   None],
#  [3,
#   2017,
#   &#39;Rajkot&#39;,
#   &#39;2017-04-07&#39;,
#   &#39;Gujarat Lions&#39;,
#   &#39;Kolkata Knight Riders&#39;,
#   &#39;Kolkata Knight Riders&#39;,
#   &#39;field&#39;,
#   &#39;normal&#39;,
#   0,
#   &#39;Kolkata Knight Riders&#39;,
#   0,
#   10,
#   &#39;CA Lynn&#39;,
#   &#39;Saurashtra Cricket Association Stadium&#39;,
#   &#39;Nitin Menon&#39;,
#   &#39;CK Nandan&#39;,
#   None],
#  [4,
#   2017,
#   &#39;Indore&#39;,
#   &#39;2017-04-08&#39;,
#   &#39;Rising Pune Supergiant&#39;,
#   &#39;Kings XI Punjab&#39;,
#   &#39;Kings XI Punjab&#39;,
#   &#39;field&#39;,
#   &#39;normal&#39;,
#   0,
#   &#39;Kings XI Punjab&#39;,
#   0,
#   6,
#   &#39;GJ Maxwell&#39;,
#   &#39;Holkar Cricket Stadium&#39;,
#   &#39;AK Chaudhary&#39;,
#   &#39;C Shamshuddin&#39;,
#   None],
#  [5,
#   2017,
#   &#39;Bangalore&#39;,
#   &#39;2017-04-08&#39;,
#   &#39;Royal Challengers Bangalore&#39;,
#   &#39;Delhi Daredevils&#39;,
#   &#39;Royal Challengers Bangalore&#39;,
#   &#39;bat&#39;,
#   &#39;normal&#39;,
#   0,
#   &#39;Royal Challengers Bangalore&#39;,
#   15,
#   0,
#   &#39;KM Jadhav&#39;,
#   &#39;M Chinnaswamy Stadium&#39;,
#   None,
#   None,
#   None]]</div>

# %%
# Create a view or table

temp_table_name = "MATCHES"

df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "matches_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# ------MOST TOSS WINS BY A TEAM USING RDD------ (Replaced RPS plural and sigular )
from pyspark import SparkContext, SparkConf
conf = SparkConf().setAppName("word count").setMaster("local[3]")
sc =  SparkContext.getOrCreate(conf=conf)
mymatchesrdd = sc.textFile("/FileStore/tables/matches.csv").map(lambda line: line.split(","))
#print(mymatchesrdd.take(5))
most_toss_winner = mymatchesrdd.map(lambda x:x[6])
a={'Rising Pune Supergiant' : 'Rising Pune Supergiants','Royal Challengers Bangalore':'Royal Challengers Bangalore','Kolkata Knight Riders':'Kolkata Knight Riders','Kings XI Punjab':'Kings XI Punjab','Sunrisers Hyderabad':'Sunrisers Hyderabad','Mumbai Indians':'Mumbai Indians','Gujarat Lions':'Gujarat Lions','Delhi Daredevils':'Delhi Daredevils','Chennai Super Kings':'Chennai Super Kings','Rajasthan Royals':'Rajasthan Royals','Deccan Chargers':'Deccan Chargers','Kochi Tuskers Kerala':'Kochi Tuskers Kerala','Pune Warriors':'Pune Warriors','Delhi Capitals':'Delhi Capitals','Rising Pune Supergiants':'Rising Pune Supergiants'}
most_toss_winner = most_toss_winner.filter(lambda x: x in a ).map(lambda xs : a[xs])
MTWcounts = most_toss_winner.countByValue()
for team, count in MTWcounts.items():
  print("{} : {}".format(team, count))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Royal Challengers Bangalore : 81
# Rising Pune Supergiants : 13
# Kolkata Knight Riders : 92
# Kings XI Punjab : 81
# Sunrisers Hyderabad : 46
# Mumbai Indians : 98
# Gujarat Lions : 15
# Delhi Daredevils : 80
# Chennai Super Kings : 89
# Rajasthan Royals : 80
# Deccan Chargers : 43
# Kochi Tuskers Kerala : 8
# Pune Warriors : 20
# Delhi Capitals : 10
# </div>

# %%
# %sql
select * from matches;
select toss_winner,count(*) as TOSS_WINS from matches group by toss_winner order by 2 desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
>5</td></tr><tr><td>KC Sangakkara</td><td>5</td></tr><tr><td>PA Patel</td><td>5</td></tr><tr><td>SPD Smith</td><td>5</td></tr><tr><td>JP Faulkner</td><td>5</td></tr><tr><td>KL Rahul</td><td>4</td></tr><tr><td>JP Duminy</td><td>4</td></tr><tr><td>N Rana</td><td>4</td></tr><tr><td>SS Iyer</td><td>4</td></tr><tr><td>MK Pandey</td><td>4</td></tr><tr><td>KD Karthik</td><td>4</td></tr><tr><td>ML Hayden</td><td>4</td></tr><tr><td>SK Warne</td><td>4</td></tr><tr><td>CA Lynn</td><td>4</td></tr><tr><td>AR Patel</td><td>4</td></tr><tr><td>F du Plessis</td><td>4</td></tr><tr><td>NM Coulter-Nile</td><td>4</td></tr><tr><td>KH Pandya</td><td>4</td></tr><tr><td>null</td><td>4</td></tr><tr><td>A Kumble</td><td>3</td></tr><tr><td>LRPL Taylor</td><td>3</td></tr><tr><td>LMP Simmons</td><td>3</td></tr><tr><td>MK Tiwary</td><td>3</td></tr><tr><td>PP Chawla</td><td>3</td></tr><tr><td>BA Stokes</td><td>3</td></tr><tr><td>R Vinay Kumar</td><td>3</td></tr><tr><td>DJ Bravo</td><td>3</td></tr><tr><td>KP Pietersen</td><td>3</td></tr><tr><td>L Balaji</td><td>3</td></tr><tr><td>DA Miller</td><td>3</td></tr><tr><td>KS Williamson</td><td>3</td></tr><tr><td>Mandeep Singh</td><td>3</td></tr><tr><td>M Vohra</td><td>3</td></tr><tr><td>CJ Anderson</td><td>3</td></tr><tr><td>WP Saha</td><td>3</td></tr><tr><td>A Symonds</td><td>3</td></tr><tr><td>KK Nair</td><td>3</td></tr><tr><td>KM Jadhav</td><td>2</td></tr><tr><td>SM Pollock</td><td>2</td></tr><tr><td>JA Morkel</td><td>2</td></tr><tr><td>P Kumar</td><td>2</td></tr><tr><td>MG Johnson</td><td>2</td></tr><tr><td>M Muralitharan</td><td>2</td></tr><tr><td>Shakib Al Hasan</td><td>2</td></tr><tr><td>AS Yadav</td><td>2</td></tr><tr><td>Iqbal Abdulla</td><td>2</td></tr><tr><td>IK Pathan</td><td>2</td></tr><tr><td>ST Jayasuriya</td><td>2</td></tr><tr><td>MM Patel</td><td>2</td></tr><tr><td>PV Tambe</td><td>2</td></tr><tr><td>S Gopal</td><td>2</td></tr><tr><td>B Lee</td><td>2</td></tr><tr><td>HV Patel</td><td>2</td></tr><tr><td>MP Stoinis</td><td>2</td></tr><tr><td>AB Dinda< ...

# %%
# Season & MATCH count 
mymatchesrdd = sc.textFile("/FileStore/tables/matches.csv").map(lambda line: line.split(","))
season_rdd = mymatchesrdd.map(lambda x:x[1]).filter(lambda x:x!='season')
season_year=season_rdd.countByValue()
for a,b in season_year.items():
  print(a,b)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2017 59
# 2008 58
# 2009 57
# 2010 60
# 2011 73
# 2012 74
# 2013 76
# 2014 60
# 2015 59
# 2016 60
# 2018 60
# 2019 60
# </div>

# %%
#Details of TIED matches
mymatchesrdd = sc.textFile("/FileStore/tables/matches.csv").map(lambda line: line.split(","))
mymatchesrdd=mymatchesrdd.filter(lambda x:x[8]=='tie').map(lambda w: w[0]+" "+str(w[4])+" VS "+str(w[5])+" Ended In a TIE ")
mymatchesrdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [&#39;34 Gujarat Lions VS Mumbai Indians Ended In a TIE &#39;,
#  &#39;126 Rajasthan Royals VS Kolkata Knight Riders Ended In a TIE &#39;,
#  &#39;190 Kings XI Punjab VS Chennai Super Kings Ended In a TIE &#39;,
#  &#39;388 Royal Challengers Bangalore VS Sunrisers Hyderabad Ended In a TIE &#39;,
#  &#39;401 Delhi Daredevils VS Royal Challengers Bangalore Ended In a TIE &#39;,
#  &#39;476 Rajasthan Royals VS Kolkata Knight Riders Ended In a TIE &#39;,
#  &#39;536 Rajasthan Royals VS Kings XI Punjab Ended In a TIE &#39;,
#  &#39;11146 Kolkata Knight Riders VS Delhi Capitals Ended In a TIE &#39;,
#  &#39;11342 Mumbai Indians VS Sunrisers Hyderabad Ended In a TIE &#39;]</div>

# %%
mymatchesrdd = sc.textFile("/FileStore/tables/matches.csv").map(lambda line: line.split(","))
row1=mymatchesrdd.first()
mymatchesrdd=mymatchesrdd.filter(lambda w:w!=row1).map(lambda w:(w[2],w[7])).reduceByKey(lambda a,b : a+b).map(lambda z:z[0] + " FIELD : " + str(z[1].count('field')) + " BAT : " + str(z[1].count('bat'))).filter(lambda z:z[0]!= " ")
#'fieldfieldbat'
mymatchesrdd.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[79]: [&#39;Mumbai FIELD : 66 BAT : 35&#39;,
#  &#39;Chandigarh FIELD : 30 BAT : 16&#39;,
#  &#39;Jaipur FIELD : 28 BAT : 19&#39;,
#  &#39;Chennai FIELD : 21 BAT : 36&#39;,
#  &#39;Port Elizabeth FIELD : 0 BAT : 7&#39;,
#  &#39;Centurion FIELD : 6 BAT : 6&#39;,
#  &#39;East London FIELD : 0 BAT : 3&#39;,
#  &#39;Johannesburg FIELD : 6 BAT : 2&#39;,
#  &#39;Kimberley FIELD : 1 BAT : 2&#39;,
#  &#39;Bloemfontein FIELD : 1 BAT : 1&#39;,
#  &#39;Cuttack FIELD : 5 BAT : 2&#39;,
#  &#39;Nagpur FIELD : 1 BAT : 2&#39;,
#  &#39;Dharamsala FIELD : 8 BAT : 1&#39;,
#  &#39;Kochi FIELD : 3 BAT : 2&#39;,
#  &#39;Visakhapatnam FIELD : 8 BAT : 5&#39;,
#  &#39;Mohali FIELD : 9 BAT : 1&#39;,
#  &#39;Hyderabad FIELD : 36 BAT : 28&#39;,
#  &#39;Pune FIELD : 21 BAT : 17&#39;,
#  &#39;Rajkot FIELD : 7 BAT : 3&#39;,
#  &#39;Indore FIELD : 8 BAT : 1&#39;,
#  &#39;Bangalore FIELD : 57 BAT : 9&#39;,
#  &#39;Kolkata FIELD : 49 BAT : 28&#39;,
#  &#39;Delhi FIELD : 42 BAT : 32&#39;,
#  &#39;Kanpur FIELD : 4 BAT : 0&#39;,
#  &#39;Cape Town FIELD : 3 BAT : 4&#39;,
#  &#39;Durban FIELD : 5 BAT : 10&#39;,
#  &#39;Ahmedabad FIELD : 6 BAT : 6&#39;,
#  &#39;Raipur FIELD : 3 BAT : 3&#39;,
#  &#39;Ranchi FIELD : 4 BAT : 3&#39;,
#  &#39;Abu Dhabi FIELD : 3 BAT : 4&#39;,
#  &#39;Sharjah FIELD : 4 BAT : 2&#39;,
#  &#39;Bengaluru FIELD : 14 BAT : 0&#39;]</div>

# %%
# UMPIRES AND THEIR STANDINGS
mymatchesrdd = sc.textFile("/FileStore/tables/matches.csv").map(lambda line: line.split(","))
a={}
mymatchesrdd=mymatchesrdd.filter(lambda w : w[0]!='id').map(lambda z:(z[-2],z[-3])).filter(lambda z:(z[0],z[1])!= ('','')).flatMap(lambda w:w)
UMPCounts = mymatchesrdd.countByValue()
for word, count in UMPCounts.items():
  print("{} : {}".format(word, count))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">NJ Llong : 25
# AY Dandekar : 13
# S Ravi : 106
# A Nand Kishore : 16
# CK Nandan : 41
# Nitin Menon : 42
# C Shamshuddin : 73
# AK Chaudhary : 58
# A Deshmukh : 6
# KN Ananthapadmanabhan : 14
# YC Barde : 4
# VK Sharma : 9
# CB Gaffaney : 24
# M Erasmus : 54
# RE Koertzen : 41
# Asad Rauf : 51
# SL Shastri : 14
# MR Benson : 12
# GA Pratapkumar : 6
# Aleem Dar : 38
# DJ Harper : 27
# SJ Davis : 7
# K Hariharan : 21
# BF Bowden : 37
# RB Tiffin : 30
# AM Saheba : 26
# IL Howell : 14
# AV Jayaprakash : 6
# I Shivram : 6
# BR Doctrove : 42
# BG Jerling : 17
# SD Ranade : 2
# SJA Taufel : 55
# TH Wijewardene : 5
# HDPK Dharmasena : 87
# S Asnani : 30
# GAV Baxter : 7
# SK Tarapore : 31
# SS Hazare : 17
# S Das : 15
# PR Reiffel : 11
# AL Hill : 6
# RJ Tucker : 38
# JD Cloete : 17
# VA Kulkarni : 39
# BNJ Oxenford : 32
# K Srinath : 15
# Subroto Das : 1
# RK Illingworth : 19
# RM Deshpande : 7
# PG Pathak : 8
# SD Fry : 6
# K Srinivasan : 3
# K Bharatan : 3
# A Nanda Kishore : 5
# Chris Gaffaney : 9
# K Ananthapadmanabhan : 6
# Rod Tucker : 9
# A.D Deshmukh : 6
# Vineet Kulkarni : 8
# Nigel Llong : 12
# Anil Chaudhary : 21
# O Nandan : 16
# Virender Kumar Sharma : 6
# Yeshwant Barde : 12
# Bruce Oxenford : 15
# Anil Dandekar : 12
# Marais Erasmus : 11
# Kumar Dharmasena : 7
# KN Anantapadmanabhan : 3
# Ulhas Gandhe : 5
# Nanda Kishore : 3
# Ian Gould : 6
# Nand Kishore : 1
# Sundaram Ravi : 1
# </div>

# %%
# MOST DL METHOD TEAM (Sorted Reverse)
mymatchesrdd = sc.textFile("/FileStore/tables/matches.csv").map(lambda line: line.split(","))
mymatchesrdd = mymatchesrdd.filter(lambda w : w[0]!='id').filter(lambda w: w[9]=='1').map(lambda w: [w[4],w[5]]).flatMap(lambda w:w)
Rain_inter_team_count=mymatchesrdd.countByValue()
#filter(lambda w:w[9] if(w[9] == 1))
for word, count in sorted(Rain_inter_team_count.items(),key=lambda w:w[1],reverse=True):
  print("{} : {}".format(word, count))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Kolkata Knight Riders : 8
# Delhi Daredevils : 6
# Kings XI Punjab : 6
# Sunrisers Hyderabad : 5
# Chennai Super Kings : 4
# Royal Challengers Bangalore : 3
# Rising Pune Supergiants : 3
# Rajasthan Royals : 2
# Kochi Tuskers Kerala : 1
# </div>
